# %% [markdown]
# ### Create a sale data analysis of any commercial store.

# %% [markdown]
# ### importing Libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ### importing data set

# %%
df = pd.read_csv(r"C:\Users\Meharaj\Downloads\archive\Top 50 Fast-Food Chains in USA.csv")

# %%
df
# Out:
#                           Fast-Food Chains  \
# 0                                   Arby’s
# 1                           Baskin-Robbins
# 2                                Bojangles
# 3                              Burger King
# 4                               Carl’s Jr.
# 5                         Checkers/Rally’s
# 6                              Chick-fil-A
# 7                                 Chipotle
# 8                         Church’s Chicken
# 9                                 Culver’s
# 10                             Dairy Queen
# 11                                Del Taco
# 12                                Domino's
# 13                                 Dunkin'
# 14                           El Pollo Loco
# 15                          Firehouse Subs
# 16                               Five Guys
# 17  Freddy’s Frozen Custard & Steakburgers
# 18                                Hardee’s
# 19                         In-N-Out Burger
# 20                         Jack in the Box
# ...

# %% [markdown]
# ### Data Description

# %%
df.head() #head: This shows the first 5 rows by default.
# Out:
#   Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 0           Arby’s                                            4462
# 1   Baskin-Robbins                                             686
# 2        Bojangles                                            1485
# 3      Burger King                                           10033
# 4       Carl’s Jr.                                            1560
#
#    Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 0                                              1309               2293
# 1                                               296               2317
# 2                                              1924                496
# 3                                              1470               7054
# 4                                              1400               1011
#
#    Company Stores  2021 Total Units  Total Change in Units from 2020
# ...

# %%
df.info() #info : This method provides an overview of the dataset, including column names, data types, non-null values, and memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Fast-Food Chains                                  50 non-null     object
#  1   U.S. Systemwide Sales (Millions - U.S Dollars)    50 non-null     int64
#  2   Average Sales per Unit (Thousands - U.S Dollars)  50 non-null     int64
#  3   Franchised Stores                                 50 non-null     int64
#  4   Company Stores                                    50 non-null     int64
#  5   2021 Total Units                                  50 non-null     int64
#  6   Total Change in Units from 2020                   50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
df.describe() #describe :This function computes statistical summaries like mean, median, standard deviation, etc., for numeric columns.
# Out:
#        U.S. Systemwide Sales (Millions - U.S Dollars)  \
# count                                       50.000000
# mean                                      4965.060000
# std                                       7531.439444
# min                                        615.000000
# 25%                                        935.250000
# 50%                                       2289.500000
# 75%                                       5400.000000
# max                                      45960.000000
#
#        Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# count                                         50.000000           50.00000
# mean                                        1857.660000         2663.96000
# std                                         1163.266418         3801.49754
# min                                          296.000000            0.00000
# 25%                                         1084.000000          478.00000
# ...

# %%
df.shape #shape: attribute in pandas is used to check the dimensions of a DataFrame
# Out:
# (50, 7)

# %%
df.tail() #tail : method in pandas is used to display the last 5 rows of a DataFrame by default
# Out:
#    Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 45          Wendy's                                           11111
# 46      Whataburger                                            3089
# 47     White Castle                                             615
# 48         Wingstop                                            2278
# 49          Zaxby’s                                            2233
#
#     Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 45                                              1895               5535
# 46                                              3640                131
# 47                                              1749                  0
# 48                                              1592               1498
# 49                                              2484                761
#
#     Company Stores  2021 Total Units  Total Change in Units from 2020
# ...

# %%
df.dtypes #dtypes = Incorrect data types can cause issues during analysis.
# Out:
# Fast-Food Chains                                    object
# U.S. Systemwide Sales (Millions - U.S Dollars)       int64
# Average Sales per Unit (Thousands - U.S Dollars)     int64
# Franchised Stores                                    int64
# Company Stores                                       int64
# 2021 Total Units                                     int64
# Total Change in Units from 2020                      int64
# dtype: object

# %%
df.columns #columns : attribute in pandas is used to display the column labels (names) of a DataFrame
# Out:
# Index(['Fast-Food Chains', 'U.S. Systemwide Sales (Millions - U.S Dollars)',
#        'Average Sales per Unit (Thousands - U.S Dollars)', 'Franchised Stores',
#        'Company Stores', '2021 Total Units',
#        'Total Change in Units from 2020'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning

# %%
df.isnull().sum() #isnull().sum():method  is used to identify missing values in each column and return the count of null values for every column.
# Out:
# Fast-Food Chains                                    0
# U.S. Systemwide Sales (Millions - U.S Dollars)      0
# Average Sales per Unit (Thousands - U.S Dollars)    0
# Franchised Stores                                   0
# Company Stores                                      0
# 2021 Total Units                                    0
# Total Change in Units from 2020                     0
# dtype: int64

# %% [markdown]
# ### **From the given dataset we conclude that their is No Missing Values.**

# %% [markdown]
# ### Duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###  **There are No Duplicates From the given Dataset.**

# %% [markdown]
# ### Outliers

# %%
plt.figure(figsize = (5,3))
df['U.S. Systemwide Sales (Millions - U.S Dollars)'].plot(kind='box')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (5,3))
df['Average Sales per Unit (Thousands - U.S Dollars)'].plot(kind='box')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (5,3))
df['Franchised Stores'].plot(kind='box')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (5,3))
df['Company Stores'].plot(kind='box')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (5,3))
df['2021 Total Units'].plot(kind='box')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (5,3))
df['Total Change in Units from 2020'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# ### **There are  Outliers from the given dataset**

# %% [markdown]
# ### Type Casting

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Fast-Food Chains                                  50 non-null     object
#  1   U.S. Systemwide Sales (Millions - U.S Dollars)    50 non-null     int64
#  2   Average Sales per Unit (Thousands - U.S Dollars)  50 non-null     int64
#  3   Franchised Stores                                 50 non-null     int64
#  4   Company Stores                                    50 non-null     int64
#  5   2021 Total Units                                  50 non-null     int64
#  6   Total Change in Units from 2020                   50 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.9+ KB

# %%
df.head()
# Out:
#   Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 0           Arby’s                                            4462
# 1   Baskin-Robbins                                             686
# 2        Bojangles                                            1485
# 3      Burger King                                           10033
# 4       Carl’s Jr.                                            1560
#
#    Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 0                                              1309               2293
# 1                                               296               2317
# 2                                              1924                496
# 3                                              1470               7054
# 4                                              1400               1011
#
#    Company Stores  2021 Total Units  Total Change in Units from 2020
# ...

# %%
df.columns
# Out:
# Index(['Fast-Food Chains', 'U.S. Systemwide Sales (Millions - U.S Dollars)',
#        'Average Sales per Unit (Thousands - U.S Dollars)', 'Franchised Stores',
#        'Company Stores', '2021 Total Units',
#        'Total Change in Units from 2020'],
#       dtype='object')

# %% [markdown]
# ## UniVariate Analysis

# %%
df.head()
# Out:
#   Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 0           Arby’s                                            4462
# 1   Baskin-Robbins                                             686
# 2        Bojangles                                            1485
# 3      Burger King                                           10033
# 4       Carl’s Jr.                                            1560
#
#    Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 0                                              1309               2293
# 1                                               296               2317
# 2                                              1924                496
# 3                                              1470               7054
# 4                                              1400               1011
#
#    Company Stores  2021 Total Units  Total Change in Units from 2020
# ...

# %% [markdown]
# ### HISTOGRAM PLOT = A histogram plot is a graphical representation of the distribution of numerical data. It groups the data into bins (intervals) and displays the frequency of data points in each bin as rectangular bars.

# %%
df["U.S. Systemwide Sales (Millions - U.S Dollars)"].min()
# Out:
# 615

# %%
df["U.S. Systemwide Sales (Millions - U.S Dollars)"].max()
# Out:
# 45960

# %%
df["U.S. Systemwide Sales (Millions - U.S Dollars)"].mean()
# Out:
# 4965.06

# %%
df[df["U.S. Systemwide Sales (Millions - U.S Dollars)"]==615]
# Out:
#    Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 47     White Castle                                             615
#
#     Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 47                                              1749                  0
#
#     Company Stores  2021 Total Units  Total Change in Units from 2020
# 47             349               349                               -6

# %%
df[df["U.S. Systemwide Sales (Millions - U.S Dollars)"]==45960]
# Out:
#    Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 28       McDonald’s                                           45960
#
#     Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 28                                              3420              12775
#
#     Company Stores  2021 Total Units  Total Change in Units from 2020
# 28             663             13438                              244

# %%
plt.figure(figsize = (6,3))
colors = ['brown', 'green']
plt.figure(figsize = (9,4))
df['U.S. Systemwide Sales (Millions - U.S Dollars)'].plot(kind= 'hist',edgecolor = 'black',color = colors)
plt.title('Frequency distribution of the U.S. Systemwide Sales (Millions - U.S Dollars)')
plt.xlabel("U.S. Systemwide Sales (Millions - U.S Dollars)") 
plt.show()

# %%
df["Average Sales per Unit (Thousands - U.S Dollars)"].min()
# Out:
# 296

# %%
df["Average Sales per Unit (Thousands - U.S Dollars)"].max()
# Out:
# 6100

# %%
df["Average Sales per Unit (Thousands - U.S Dollars)"].mean()
# Out:
# 1857.66

# %%
df[df["Average Sales per Unit (Thousands - U.S Dollars)"] == 296]
# Out:
#   Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 1   Baskin-Robbins                                             686
#
#    Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 1                                               296               2317
#
#    Company Stores  2021 Total Units  Total Change in Units from 2020
# 1               0              2317                              102

# %%
df[df["Average Sales per Unit (Thousands - U.S Dollars)"] == 6100]
# Out:
#   Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 6      Chick-fil-A                                           16700
#
#    Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 6                                              6100               2650
#
#    Company Stores  2021 Total Units  Total Change in Units from 2020
# 6              82              2732                              155

# %%
plt.figure(figsize = (9,4))
df['Average Sales per Unit (Thousands - U.S Dollars)'].value_counts().plot(kind='kde',color = "pink")
plt.title('Frequency distribution of the Average Sales per Unit (Thousands - U.S Dollars)')
plt.show()

# %%
df["Franchised Stores"].min()
# Out:
# 0

# %%
df["Franchised Stores"].max()
# Out:
# 21147

# %%
df["Franchised Stores"].mean()
# Out:
# 2663.96

# %%
df[df["Franchised Stores"]==0]
# Out:
#    Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 7          Chipotle                                            7547
# 19  In-N-Out Burger                                            1175
# 47     White Castle                                             615
#
#     Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 7                                               2641                  0
# 19                                              3200                  0
# 47                                              1749                  0
#
#     Company Stores  2021 Total Units  Total Change in Units from 2020
# 7             2966              2966                              198
# 19             370               370                                5
# 47             349               349                               -6

# %%
df[df["Franchised Stores"]==21147]
# Out:
#    Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 41           Subway                                            9350
#
#     Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 41                                               438              21147
#
#     Company Stores  2021 Total Units  Total Change in Units from 2020
# 41               0             21147                            -1043

# %%
plt.figure(figsize = (9,4))
sns.boxplot(data = df, x = "Franchised Stores",color = "green")
plt.title('Frequency distribution of the Franchised Stores')
plt.show()

# %%
df["Company Stores"].min()
# Out:
# 0

# %%
df["Company Stores"].max()
# Out:
# 8953

# %%
df["Company Stores"].mean()
# Out:
# 503.5

# %%
df[df["Company Stores"] == 0]
# Out:
#    Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 1    Baskin-Robbins                                             686
# 13          Dunkin'                                           10416
# 41           Subway                                            9350
# 43      Tim Hortons                                             687
#
#     Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 1                                                296               2317
# 13                                              1127               9244
# 41                                               438              21147
# 43                                              1200                637
#
#     Company Stores  2021 Total Units  Total Change in Units from 2020
# 1                0              2317                              102
# 13               0              9244                              161
# ...

# %%
df[df["Company Stores"] == 8953]
# Out:
#    Fast-Food Chains  U.S. Systemwide Sales (Millions - U.S Dollars)  \
# 40        Starbucks                                           24300
#
#     Average Sales per Unit (Thousands - U.S Dollars)  Franchised Stores  \
# 40                                              1200               6497
#
#     Company Stores  2021 Total Units  Total Change in Units from 2020
# 40            8953             15450                              113

# %%
plt.figure(figsize = (9,4))
sns.violinplot(data = df, x = "Company Stores",color = "red")
plt.title('Frequency distribution of the Company Stores ')
plt.show()

# %%
plt.figure(figsize = (9,4))
sns.kdeplot(data = df, x = "2021 Total Units",color = "lightblue")
plt.title('Frequency distribution of the 2021 Total Units')
plt.show()

# %%
plt.figure(figsize = (9,4))
sns.kdeplot(data = df, x = "Total Change in Units from 2020",color = "lightblue")
plt.title('Frequency distribution of the Total Change in Units from 2020')
plt.show()

# %% [markdown]
# ### bivariate analysis

# %%
df
# Out:
#                           Fast-Food Chains  \
# 0                                   Arby’s
# 1                           Baskin-Robbins
# 2                                Bojangles
# 3                              Burger King
# 4                               Carl’s Jr.
# 5                         Checkers/Rally’s
# 6                              Chick-fil-A
# 7                                 Chipotle
# 8                         Church’s Chicken
# 9                                 Culver’s
# 10                             Dairy Queen
# 11                                Del Taco
# 12                                Domino's
# 13                                 Dunkin'
# 14                           El Pollo Loco
# 15                          Firehouse Subs
# 16                               Five Guys
# 17  Freddy’s Frozen Custard & Steakburgers
# 18                                Hardee’s
# 19                         In-N-Out Burger
# 20                         Jack in the Box
# ...

# %% [markdown]
# ### Numerical vs. Numerical

# %%
sns.scatterplot(x=df['U.S. Systemwide Sales (Millions - U.S Dollars)'], y=df['Average Sales per Unit (Thousands - U.S Dollars)'])
plt.show()

# %%
correlation_matrix = df.select_dtypes(include=['number']).corr()
correlation_matrix
# Out:
#                                                   U.S. Systemwide Sales (Millions - U.S Dollars)  \
# U.S. Systemwide Sales (Millions - U.S Dollars)                                          1.000000
# Average Sales per Unit (Thousands - U.S Dollars)                                        0.231458
# Franchised Stores                                                                       0.628534
# Company Stores                                                                          0.400637
# 2021 Total Units                                                                        0.708770
# Total Change in Units from 2020                                                         0.167489
#
#                                                   Average Sales per Unit (Thousands - U.S Dollars)  \
# U.S. Systemwide Sales (Millions - U.S Dollars)                                            0.231458
# ...

# %%
sns.jointplot(x=df['Franchised Stores'], y=df['Company Stores'], kind='scatter')
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# ### multivariate analysis

# %%
plt.figure(figsize=(10,6))
sns.heatmap( df.select_dtypes(include=['number']).corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.show()
